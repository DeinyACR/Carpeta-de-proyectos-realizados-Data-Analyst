# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
# Diccionario de paises
df_cat_pais = pd.read_csv('https://raw.githubusercontent.com/jsaraujott/datos/refs/heads/main/cat_codpais3.csv')

# %%
# DF ahorro
df_ahorro = pd.read_csv('https://raw.githubusercontent.com/jsaraujott/datos/refs/heads/main/wb_ahorro.csv')

# %%
# DF crecimiento pib
df_pib = pd.read_csv('https://raw.githubusercontent.com/jsaraujott/datos/refs/heads/main/wb_crecimpib.csv')

# %%
# DF crecimiento poblacional 
df_poblacion = pd.read_csv('https://raw.githubusercontent.com/jsaraujott/datos/refs/heads/main/wb_crecimpob.csv')

# %%
# DF pobloacion urbana 
df_urbana = pd.read_csv('https://raw.githubusercontent.com/jsaraujott/datos/refs/heads/main/wb_poburbana.csv')

# %% [markdown]
# # Diagnistico inicial

# %%
df_cat_pais.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Code  264 non-null    object
#  1   Country Name  264 non-null    object
# dtypes: object(2)
# memory usage: 4.3+ KB

# %%
df_cat_pais.sample(10)
# Out:
#     Country Code                 Country Name
# 106          IMN                  Isla de Man
# 99           HUN                      Hungría
# 200          RUS          Federación de Rusia
# 9            ASM              Samoa Americana
# 11           AUS                    Australia
# 198          QAT                        Qatar
# 148          MDA         República de Moldova
# 69           EST                      Estonia
# 130          LBY                        Libia
# 61           EAS  Asia oriental y el Pacífico

# %%
df_ahorro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 25 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Code  265 non-null    object
#  1   2000          161 non-null    float64
#  2   2001          160 non-null    float64
#  3   2002          167 non-null    float64
#  4   2003          169 non-null    float64
#  5   2004          169 non-null    float64
#  6   2005          187 non-null    float64
#  7   2006          190 non-null    float64
#  8   2007          195 non-null    float64
#  9   2008          196 non-null    float64
#  10  2009          198 non-null    float64
#  11  2010          200 non-null    float64
#  12  2011          201 non-null    float64
#  13  2012          204 non-null    float64
#  14  2013          204 non-null    float64
#  15  2014          206 non-null    float64
#  16  2015          207 non-null    float64
# ...

# %%
df_ahorro.sample(10)
# Out:
#     Country Code       2000       2001       2002       2003       2004  \
# 17           BEL        NaN        NaN  26.371768  26.224229  27.194348
# 238          TMN        NaN        NaN        NaN        NaN        NaN
# 251          USA  20.813335  19.657276  18.380860  17.428715  17.733161
# 201          ROU  16.005476  17.310206  18.821391  16.322530  15.809860
# 154          MEX  20.860015  20.804545  20.560379  19.782321  21.468439
# 55           DEU  22.668918  22.540648  22.639590  21.796395  24.320947
# 220          SUR        NaN        NaN        NaN        NaN        NaN
# 23           BHS  32.684911  28.743915  32.121540  31.202276  32.700775
# 60           DZA        NaN        NaN        NaN        NaN        NaN
# 30           BRB  10.651947   8.493279   9.521741  11.846799   8.124926
#
#           2005       2006       2007       2008  ...       2014       2015  \
# 17   27.316822  27.848001  28.779585  27.427341  ...  24.577123  25.008678
# ...
