# %% [markdown]
# Carga de datos y copia local

# %%
# Carga de librerias 
import pandas as pd

# %%
# Carga de datos 
df = pd.read_csv('games.csv')

# %%
# Copia de respaldo
df.to_csv('df_games.csv', index = False)
